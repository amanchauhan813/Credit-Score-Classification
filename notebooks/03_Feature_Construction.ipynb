# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='C:\\Users\\amanc\\Desktop\\python new project\\Machine Learning\\Credit Score Classification\\data\\clean_train.csv'
data=pd.read_csv(path)

# %%
data.head()
# Out:
#    Unnamed: 0 Customer_ID        SSN  Age     Occupation  Annual_Income  \
# 0           0  CUS_0x1000  913741218   17         Lawyer       30625.94
# 1           1  CUS_0x1009   63676938   25       Mechanic       52312.68
# 2           2  CUS_0x100b  238620395   18  Media_Manager      113781.39
# 3           3  CUS_0x1011  793058223   43         Doctor       58918.47
# 4           4  CUS_0x1013  930499615   43       Mechanic       98620.98
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0                2706.16                  6                5           27.0
# 1                4250.39                  6                5           17.0
# 2                9549.78                  1                4            1.0
# 3                5208.87                  3                3           17.0
# 4                7962.42                  3                3            6.0
#
#    ...  Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0  ...         Bad          1562.91                  33.47750
# 1  ...    Standard           202.68                  29.84000
# 2  ...        Good          1030.20                  34.84250
# 3  ...    Standard           473.14                  27.65625
# 4  ...        Good          1233.51                  31.93375
#
#       Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0  10 Years and 2 Months                    Yes                42.94
# 1  30 Years and 5 Months                    Yes               108.37
# 2  15 Years and 3 Months                     No                 0.00
# 3  15 Years and 3 Months                    Yes               123.43
# 4  17 Years and 3 Months                     No               228.02
#
#   Amount_invested_monthly                 Payment_Behaviour  Monthly_Balance  \
# 0               158.54875    Low_spent_Large_value_payments        335.37500
# 1               146.67875   Low_spent_Medium_value_payments        428.74250
# 2               544.44375   Low_spent_Medium_value_payments        781.23125
# 3               281.08250   High_spent_Large_value_payments        332.64250
# 4               355.44125  High_spent_Medium_value_payments        472.78125
#
#   Credit_Score
# 0         Poor
# 1     Standard
# 2         Poor
# 3     Standard
# 4     Standard
#
# [5 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Customer_ID', 'SSN', 'Age', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0','Customer_ID','SSN'],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#    Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0   17         Lawyer       30625.94                2706.16
# 1   25       Mechanic       52312.68                4250.39
# 2   18  Media_Manager      113781.39                9549.78
# 3   43         Doctor       58918.47                5208.87
# 4   43       Mechanic       98620.98                7962.42
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  6                5           27.0            2
# 1                  6                5           17.0            4
# 2                  1                4            1.0            0
# 3                  3                3           17.0            3
# 4                  3                3            6.0            3
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0          Credit-Builder Loan, and Home Equity Loan                   57
# 1  Not Specified, Home Equity Loan, Credit-Builde...                    7
# 2                                            No Loan                   13
# 3  Student Loan, Credit-Builder Loan, and Debt Co...                   27
# 4  Student Loan, Debt Consolidation Loan, and Per...                   12
#
#    ...  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0  ...         Bad           1562.91                  33.47750
# 1  ...    Standard            202.68                  29.84000
# 2  ...        Good           1030.20                  34.84250
# 3  ...    Standard            473.14                  27.65625
# 4  ...        Good           1233.51                  31.93375
#
#       Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0  10 Years and 2 Months                    Yes                42.94
# 1  30 Years and 5 Months                    Yes               108.37
# 2  15 Years and 3 Months                     No                 0.00
# 3  15 Years and 3 Months                    Yes               123.43
# 4  17 Years and 3 Months                     No               228.02
#
#   Amount_invested_monthly                 Payment_Behaviour  Monthly_Balance  \
# 0               158.54875    Low_spent_Large_value_payments        335.37500
# 1               146.67875   Low_spent_Medium_value_payments        428.74250
# 2               544.44375   Low_spent_Medium_value_payments        781.23125
# 3               281.08250   High_spent_Large_value_payments        332.64250
# 4               355.44125  High_spent_Medium_value_payments        472.78125
#
#    Credit_Score
# 0          Poor
# 1      Standard
# 2          Poor
# 3      Standard
# 4      Standard
#
# [5 rows x 23 columns]

# %%
data['Occupation'].unique()
# Out:
# array(['Lawyer', 'Mechanic', 'Media_Manager', 'Doctor', 'Journalist',
#        'Accountant', 'Manager', 'Entrepreneur', 'Scientist', 'Architect',
#        'Teacher', 'Engineer', 'Writer', 'Developer', 'Musician'],
#       dtype=object)
